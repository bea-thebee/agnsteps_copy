# %%
# %run confusion_matrix_builder.py
# Out:
# ✓ Loaded simulated data with 1000 sources
#
#
# ...
# CONFUSION MATRIX BUILDER
# ...
#
# Building general confusion matrix...
# ...
# Processing sources: 100%|██████████| 1000/1000 [00:00<00:00, 724905.63it/s]
# ✓ Built general confusion matrix (6x6)
#   Total sources: 1000
#   Accuracy: 96.50%
#
# Building resampled confusion matrix (single source, multiple detections)...
#   Selected source: 4FGL J0110.5-2259
#   True number of blocks: 0
#   Running 100 detections with noise perturbation...
# Running detections: 100%|██████████| 100/100 [00:00<00:00, 559987.18it/s]
# ✓ Built resampled confusion matrix
#   Source: 4FGL J0110.5-2259
#   True blocks: 0
#   Iterations: 100
#   Correct detections: 100 (100.0%)
#   Overestimates: 0 (0.0%)
#   Underestimates: 0 (0.0%)
#   Detection mean: 0.00
#   Detection std: 0.00
#
#
# Generating comparison plot...
# ✓ Saved: confusion_matrices_comparison.png
#
# Generating individual plots with statistics...
# ✓ Saved: general_confusion_matrix.png
# ...
